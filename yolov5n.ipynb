# %% [markdown]
# <a href="https://colab.research.google.com/github/anjalidaftary/SARDrone/blob/main/yolov5n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#this portion can also be run in the terminal without % and ! in front of each line; it's only written here for clarity

# %cd /content
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17516, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 17516 (delta 6), reused 0 (delta 0), pack-reused 17497 (from 4)
# Receiving objects: 100% (17516/17516), 16.66 MiB | 14.28 MiB/s, done.
# Resolving deltas: 100% (11997/11997), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 44.6 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow
#https://docs.roboflow.com/developer/python-sdk/using-the-python-sdk
from roboflow import Roboflow
rf = Roboflow(api_key="API-KEY")
project = rf.workspace().project("drone-person-detection-ald8g-l1edq")
dataset = project.version(1).download("yolov5")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 47.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 109.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 113.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to drone-person-detection-1 in yolov5pytorch:: 100%|██████████| 6364/6364 [00:03<00:00, 1731.48it/s]

# %%
# !python train.py --img 640 --batch 32 --epochs 50 --data /content/yolov5/drone-person-detection-1/data.yaml --weights yolov5n.pt --name final --device 0
# Out:
# Streaming output truncated to the last 5000 lines.
#   with torch.cuda.amp.autocast(amp):
#       23/49      4.06G     0.0353    0.00883          0        152        640:  34% 30/87 [00:12<00:30,  1.88it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/49      4.06G    0.03525   0.008849          0        172        640:  34% 30/87 [00:12<00:30,  1.88it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/49      4.06G    0.03529   0.008786          0        129        640:  37% 32/87 [00:12<00:19,  2.83it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
# !cp /content/yolov5/runs/train/final/weights/best.pt /content/drive/MyDrive/ #copies model weighting into Google Drive

# %%
# %cd /content/yolov5

# %%
# !python export.py --weights /content/drive/MyDrive/best.pt --include torchscript onnx #exports model with TorchScript and ONNX
# Out:
# export: data=data/coco128.yaml, weights=['/content/drive/MyDrive/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=False, mlmodel=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'onnx']
# YOLOv5 🚀 v7.0-422-g2540fd4c Python-3.11.13 torch-2.6.0+cu124 CPU
#
# Fusing layers...
# Model summary: 157 layers, 1760518 parameters, 0 gradients, 4.1 GFLOPs
#
# PyTorch: starting from /content/drive/MyDrive/best.pt with output shape (1, 25200, 6) (3.7 MB)
#
# TorchScript: starting export with torch 2.6.0+cu124...
# TorchScript: export success ✅ 1.2s, saved as /content/drive/MyDrive/best.torchscript (7.2 MB)
#
# ONNX: starting export with onnx 1.18.0...
# ONNX: export success ✅ 0.5s, saved as /content/drive/MyDrive/best.onnx (7.1 MB)
#
# Export complete (2.0s)
# ...
